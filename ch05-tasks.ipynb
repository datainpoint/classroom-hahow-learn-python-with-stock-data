# %% [markdown]
# # 金融數據學 Python：程式邏輯與選股思維
#
# > 任務二：剔除在開曼群島註冊的公司 | The One With Bad Reputation
#
# [郭耀仁](https://hahow.in/@tonykuoyj?tr=tonykuoyj) | <yaojenkuo@datainpoint.com>

# %% [markdown]
# ## 執行下方儲存格將所需資料下載到工作目錄

# %%
# !wget -Nq https://raw.githubusercontent.com/datainpoint/classroom-hahow-learn-python-with-stock-data/refs/heads/main/datasets/top_ranking_stocks.csv

# %% [markdown]
# ## 1. 載入 `top_ranking_stocks.csv` 為 `DataFrame` 並命名為 `top_ranking_stocks_csv`

# %% [markdown]
# ## 2. 利用布林索引，將 `top_ranking_stocks_csv` 中註冊於開曼群島（-KY 註記）的觀測值篩選出來，將篩選後的資料框命名為 `ky_stocks`

# %% [markdown]
# ## 3. 利用布林索引，將 `top_ranking_stocks_csv` 中「非」註冊於開曼群島的觀測值篩選出來，將篩選後的資料框命名為 `non_ky_stocks`

# %% [markdown]
# ## 重新啟動並執行所有儲存格進行批改測試，暸解是否完成所有任務項目
#
# Runtime -> Restart session and run all -> Yes -> Run anyway.

# %%
import unittest

class TestMissionOne(unittest.TestCase):
    def test_01(self):
        self.assertEqual(top_ranking_stocks_csv.shape[0], 200)
    def test_02(self):
        self.assertTrue(ky_stocks.shape[0] < 200)
    def test_03(self):
        self.assertTrue(non_ky_stocks.shape[0] < 200)

suite = unittest.TestLoader().loadTestsFromTestCase(TestMissionOne)
runner = unittest.TextTestRunner(verbosity=2)
test_results = runner.run(suite)
number_of_failures = len(test_results.failures)
number_of_errors = len(test_results.errors)
number_of_test_runs = test_results.testsRun
number_of_successes = number_of_test_runs - (number_of_failures + number_of_errors)
chapter_name = "任務二：剔除在開曼群島註冊的公司 | The One With Bad Reputation"
print(f"恭喜你！您在「{chapter_name}」中的 {number_of_test_runs} 個任務項目完成了 {number_of_successes} 個！")
