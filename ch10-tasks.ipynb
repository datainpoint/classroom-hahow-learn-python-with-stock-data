# %% [markdown]
# # 金融數據學 Python：程式邏輯與選股思維
#
# > 任務七：剔除合併營收年增率為負的公司 | The One Where Revenue Grows
#
# [郭耀仁](https://hahow.in/@tonykuoyj?tr=tonykuoyj) | <yaojenkuo@datainpoint.com>

# %% [markdown]
# ## 執行下方儲存格將所需資料下載到工作目錄

# %%
# !wget -Nq https://raw.githubusercontent.com/datainpoint/classroom-hahow-learn-python-with-stock-data/refs/heads/main/datasets/monthly_revenues.json

# %% [markdown]
# ## 1. 載入 `monthly_revenues.json` 為 `list` 並命名為 `monthly_revenues_json`

# %% [markdown]
# ## 2. 將 `monthly_revenues_json` 中所有資料期間 `monthly_revenue` 營收年增率皆為正的公司給予 `is_revenue_yoy_positive: True`，資料期間 `monthly_revenue` 營收年增率任一期小於等於零的公司給予 `is_revenue_yoy_positive: False`，將判斷結果以 `dict` 紀錄後新增到 `list` 並命名為 `is_revenue_yoy_positive_list`
#
#
# ```
# [
#     {"ticker": "5566.TW",
#      "is_revenue_yoy_positive": True},
#     ...
#     {"ticker": "5566.TWO",
#      "is_revenue_yoy_positive": False}
# ]
# ```

# %% [markdown]
# ## 3. 將 `is_revenue_yoy_positive_list` 轉換為外型 `(200, 2)` 的資料框命名為 `is_revenue_yoy_positive_df`

# %% [markdown]
# ## 重新啟動並執行所有儲存格進行批改測試，暸解是否完成所有任務項目
#
# Runtime -> Restart session and run all -> Yes -> Run anyway.

# %%
import unittest

class TestMissionSeven(unittest.TestCase):
    def test_01(self):
        self.assertEqual(len(monthly_revenues_json), 200)
        self.assertEqual(len(monthly_revenues_json[0]), 2)
    def test_02(self):
        self.assertEqual(len(is_revenue_yoy_positive_list), 200)
        self.assertEqual(len(is_revenue_yoy_positive_list[0]), 2)
    def test_03(self):
        self.assertEqual(is_revenue_yoy_positive_df.shape[0], 200)
        self.assertEqual(is_revenue_yoy_positive_df.shape[1], 2)

suite = unittest.TestLoader().loadTestsFromTestCase(TestMissionSeven)
runner = unittest.TextTestRunner(verbosity=2)
test_results = runner.run(suite)
number_of_failures = len(test_results.failures)
number_of_errors = len(test_results.errors)
number_of_test_runs = test_results.testsRun
number_of_successes = number_of_test_runs - (number_of_failures + number_of_errors)
chapter_name = "任務七：剔除合併營收年增率為負的公司 | The One Where Revenue Grows"
print(f"恭喜你！您在「{chapter_name}」中的 {number_of_test_runs} 個任務項目完成了 {number_of_successes} 個！")
