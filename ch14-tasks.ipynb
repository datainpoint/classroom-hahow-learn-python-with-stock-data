# %% [markdown]
# # 金融數據學 Python：程式邏輯與選股思維
#
# > 結語：我的 Python 學得剛剛好 | The One Who Just Learned Enough Python
#
# [郭耀仁](https://hahow.in/@tonykuoyj?tr=tonykuoyj) | <yaojenkuo@datainpoint.com>

# %% [markdown]
# ## 執行下方儲存格將所需模組、資料下載到工作目錄

# %%
# !wget -Nq https://raw.githubusercontent.com/datainpoint/classroom-hahow-learn-python-with-stock-data/refs/heads/main/stock_filters_by_kuo_hua_huang.py
# !wget -Nq https://raw.githubusercontent.com/datainpoint/classroom-hahow-learn-python-with-stock-data/refs/heads/main/datasets/free_cashflows.json
# !wget -Nq https://raw.githubusercontent.com/datainpoint/classroom-hahow-learn-python-with-stock-data/refs/heads/main/datasets/gross_profits_and_operating_margins.json
# !wget -Nq https://raw.githubusercontent.com/datainpoint/classroom-hahow-learn-python-with-stock-data/refs/heads/main/datasets/inventory_turnovers.json
# !wget -Nq https://raw.githubusercontent.com/datainpoint/classroom-hahow-learn-python-with-stock-data/refs/heads/main/datasets/listing_dates.csv
# !wget -Nq https://raw.githubusercontent.com/datainpoint/classroom-hahow-learn-python-with-stock-data/refs/heads/main/datasets/market_caps.csv
# !wget -Nq https://raw.githubusercontent.com/datainpoint/classroom-hahow-learn-python-with-stock-data/refs/heads/main/datasets/monthly_revenues.json
# !wget -Nq https://raw.githubusercontent.com/datainpoint/classroom-hahow-learn-python-with-stock-data/refs/heads/main/datasets/top_ranking_stocks.csv
# !wget -Nq https://raw.githubusercontent.com/datainpoint/classroom-hahow-learn-python-with-stock-data/refs/heads/main/datasets/trading_volumes.db

# %% [markdown]
# ## 1. 載入 `stock_filters_by_kuo_hua_huang` 模組中的 `StockFilters` 類別，將該類別初始化的物件命名為 `stock_filters`
#
# ```python
# from module_name import class_name
# ```

# %% [markdown]
# ## 2. 呼叫 `stock_filters` 的 `get_wide_columns()` 方法，將該方法的輸出命名為 `wide_columns`

# %% [markdown]
# ## 3. 呼叫 `stock_filters` 的 `get_filtered_stocks()` 方法，將該方法的輸出命名為 `filtered_stocks`

# %% [markdown]
# ## 4. 運用 `set` 資料結構的特性與 `wide_columns`、`filtered_stocks` 找出被剔除的上市上櫃公司股票代號，命名為 `removed_tickers`

# %% [markdown]
# ## 重新啟動並執行所有儲存格進行批改測試，暸解是否完成所有任務項目
#
# Runtime -> Restart session and run all -> Yes -> Run anyway.

# %%
import unittest

class TestLastMission(unittest.TestCase):
    def test_01(self):
        answer = StockFilters()
        self.assertTrue(isinstance(stock_filters, type(answer)))
    def test_02(self):
        self.assertEqual(wide_columns.shape[0], 200)
        self.assertGreaterEqual(wide_columns.shape[1], 12)
    def test_03(self):
        self.assertLessEqual(filtered_stocks.shape[0], 200)
        self.assertGreaterEqual(filtered_stocks.shape[1], 3)
    def test_04(self):
        len_filtered_tickers = filtered_stocks["ticker"].size
        len_removied_tickers = len(removed_tickers)
        self.assertEqual(len_filtered_tickers + len_removied_tickers, 200)

suite = unittest.TestLoader().loadTestsFromTestCase(TestLastMission)
runner = unittest.TextTestRunner(verbosity=2)
test_results = runner.run(suite)
number_of_failures = len(test_results.failures)
number_of_errors = len(test_results.errors)
number_of_test_runs = test_results.testsRun
number_of_successes = number_of_test_runs - (number_of_failures + number_of_errors)
chapter_name = "結語：我的 Python 學得剛剛好 | The One Who Just Learned Enough Python"
print(f"恭喜你！您在「{chapter_name}」中的 {number_of_test_runs} 個任務項目完成了 {number_of_successes} 個！")
