# %% [markdown]
# # 金融數據學 Python：程式邏輯與選股思維
#
# > 任務九：剔除存貨周轉率連續下滑的公司 | The One Where Inventory Turns Over
#
# [郭耀仁](https://hahow.in/@tonykuoyj?tr=tonykuoyj) | <yaojenkuo@datainpoint.com>

# %% [markdown]
# ## 執行下方儲存格將所需資料下載到工作目錄

# %%
# !wget -Nq https://raw.githubusercontent.com/datainpoint/classroom-hahow-learn-python-with-stock-data/refs/heads/main/datasets/inventory_turnovers.json

# %% [markdown]
# ## 1. 載入 `inventory_turnovers.json` 為 `list` 並命名為 `inventory_turnovers_json`

# %% [markdown]
# ## 2. 將 `inventory_turnovers_json` 中所有資料期間 `inventory_turnover` 存貨周轉率任一期大於等於零的公司給予 `is_inventory_turnover_not_negative: True`，資料期間 `inventory_turnover`  存貨周轉率全部皆小於零的公司給予 `is_inventory_turnover_not_negative: False`，將判斷結果以 `dict` 紀錄後新增到 `list` 並命名為 `inventory_turnover_is_not_negative_list`
#
#
# ```
# [
#     {"ticker": "5566.TW",
#      "is_inventory_turnover_not_negative": True},
#     ...
#     {"ticker": "5566.TWO",
#      "is_inventory_turnover_not_negative": False}
# ]
# ```

# %% [markdown]
# ## 3. 將 `inventory_turnover_is_not_negative_list` 轉換為外型 `(200, 2)` 的資料框命名為 `inventory_turnover_is_not_negative_df`

# %% [markdown]
# ## 重新啟動並執行所有儲存格進行批改測試，暸解是否完成所有任務項目
#
# Runtime -> Restart session and run all -> Yes -> Run anyway.

# %%
import unittest

class TestMissionNine(unittest.TestCase):
    def test_01(self):
        self.assertEqual(len(inventory_turnovers_json), 200)
        self.assertEqual(len(inventory_turnovers_json[0]), 2)
        self.assertEqual(len(inventory_turnovers_json[-1]), 2)
    def test_02(self):
        self.assertEqual(len(inventory_turnover_is_not_negative_list), 200)
        self.assertEqual(len(inventory_turnover_is_not_negative_list[0]), 2)
        self.assertEqual(len(inventory_turnover_is_not_negative_list[-1]), 2)
    def test_03(self):
        self.assertEqual(inventory_turnover_is_not_negative_df.shape[0], 200)
        self.assertEqual(inventory_turnover_is_not_negative_df.shape[1], 2)

suite = unittest.TestLoader().loadTestsFromTestCase(TestMissionNine)
runner = unittest.TextTestRunner(verbosity=2)
test_results = runner.run(suite)
number_of_failures = len(test_results.failures)
number_of_errors = len(test_results.errors)
number_of_test_runs = test_results.testsRun
number_of_successes = number_of_test_runs - (number_of_failures + number_of_errors)
chapter_name = "任務九：剔除存貨周轉率連續下滑的公司 | The One Where Inventory Turns Over"
print(f"恭喜你！您在「{chapter_name}」中的 {number_of_test_runs} 個任務項目完成了 {number_of_successes} 個！")
